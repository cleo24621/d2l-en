# %%
import torch
from torch import nn
from d2l import torch as d2l
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 import torch
#       2 from torch import nn
# ----> 3 from d2l import torch as d2l
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\d2l\torch.py:33
#      31 import zipfile
#      32 from collections import defaultdict
# ---> 33 import pandas as pd
#      34 import requests
#      35 from IPython import display
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\pandas\__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\pandas\compat\__init__.py:25
#      17 from pandas.compat._constants import (
#      18     IS64,
#      19     PY39,
#    (...)
#      22     PYPY,
#      23 )
#      24 import pandas.compat.compressors
# ---> 25 from pandas.compat.numpy import (
#      26     is_numpy_dev,
#      27     np_version_under1p21,
#      28 )
#      29 from pandas.compat.pyarrow import (
#      30     pa_version_under7p0,
#      31     pa_version_under8p0,
#      32     pa_version_under9p0,
#      33     pa_version_under11p0,
#      34 )
#      37 def set_function_name(f: F, name: str, cls) -> F:
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\pandas\compat\numpy\__init__.py:4
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\pandas\util\__init__.py:2
#       1 # pyright: reportUnusedImport = false
# ----> 2 from pandas.util._decorators import (  # noqa:F401
#       3     Appender,
#       4     Substitution,
#       5     cache_readonly,
#       6 )
#       8 from pandas.core.util.hashing import (  # noqa:F401
#       9     hash_array,
#      10     hash_pandas_object,
#      11 )
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\pandas\util\_decorators.py:14
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly
#      15 from pandas._typing import (
#      16     F,
#      17     T,
#      18 )
#      19 from pandas.util._exceptions import find_stack_level
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\pandas\_libs\__init__.py:13
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\pandas\_libs\interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %% [markdown]
# # 11.8.2. Patch Embedding

# %%
class PatchEmbedding(nn.Module):
    def __init__(self, img_size=96, patch_size=16, num_hiddens=512):
        super().__init__()
        def _make_tuple(x):
            if not isinstance(x, (list, tuple)):
                return (x, x)
            return x
        img_size, patch_size = _make_tuple(img_size), _make_tuple(patch_size)
        self.num_patches = (img_size[0] // patch_size[0]) * (img_size[1] // patch_size[1])
        self.conv = nn.LazyConv2d(num_hiddens, kernel_size=patch_size, stride=patch_size)

    def forward(self, X):
        # Output shape: (batch_size, no. of patches, no. of channels)
        return self.conv(X).flatten(2).transpose(1, 2)

# %%
img_size, patch_size, num_hiddens, batch_size = 96, 16, 512, 4
patch_emb = PatchEmbedding(img_size, patch_size, num_hiddens)
X = torch.zeros(batch_size, 3, img_size, img_size)
d2l.check_shape(patch_emb(X), (batch_size, (img_size//patch_size)**2, num_hiddens))

# %% [markdown]
# # 11.8.3. Vision Transformer Encoder

# %%
class ViTMLP(nn.Module):
    def __init__(self, mlp_num_hiddens, mlp_num_outputs, dropout=0.5):
        super().__init__()
        self.dense1 = nn.LazyLinear(mlp_num_hiddens)
        self.gelu = nn.GELU()
        self.dropout1 = nn.Dropout(dropout)
        self.dense2 = nn.LazyLinear(mlp_num_outputs)
        self.dropout2 = nn.Dropout(dropout)

    def forward(self, x):
        return self.dropout2(self.dense2(self.dropout1(self.gelu(self.dense1(x)))))

# %%
class ViTBlock(nn.Module):
    def __init__(self, num_hiddens, norm_shape, mlp_num_hiddens, num_heads, dropout, use_bias=False):
        super().__init__()
        self.ln1 = nn.LayerNorm(norm_shape)
        self.attention = d2l.MultiHeadAttention(num_hiddens, num_heads, dropout, use_bias)
        self.ln2 = nn.LayerNorm(norm_shape)
        self.mlp = ViTMLP(mlp_num_hiddens, num_hiddens, dropout)

    def forward(self, X, valid_lens=None):
        X = X + self.attention(*([self.ln1(X)] * 3), valid_lens)
        # Equals to self.attention(self.ln1(X), self.ln1(X), self.ln1(X), valid_lens)
        return X + self.mlp(self.ln2(X))

# %%
X = torch.ones((2, 100, 24))
encoder_blk = ViTBlock(24, 24, 48, 8, 0.5)
encoder_blk.eval()
d2l.check_shape(encoder_blk(X), X.shape)
# Out:
# d:\_Software\miniconda3\envs\d2l\lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %% [markdown]
# # 11.8.4. Putting It All Together

# %%
class ViT(d2l.Classifier):
    """Vision Transformer."""
    def __init__(self, img_size, patch_size, num_hiddens, mlp_num_hiddens, num_heads, num_blks, emb_dropout, blk_dropout, lr=0.1, use_bias=False, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.patch_embedding = PatchEmbedding(img_size, patch_size, num_hiddens)
        self.cls_token = nn.Parameter(torch.zeros(1, 1, num_hiddens))
        num_steps = self.patch_embedding.num_patches + 1  # Add the cls token
        self.pos_embedding = nn.Parameter(torch.randn(1, num_steps, num_hiddens))
        self.dropout = nn.Dropout(emb_dropout)
        self.blks = nn.Sequential()
        for i in range(num_blks):
            self.blks.add_module(f"{i}", ViTBlock(num_hiddens, num_hiddens, mlp_num_hiddens, num_heads, blk_dropout, use_bias))
        self.head = nn.Sequential(nn.LayerNorm(num_hiddens), nn.Linear(num_hiddens, num_classes))

    def forward(self, X):
        X = self.patch_embedding(X)
        X = torch.cat((self.cls_token.expand(X.shape[0], -1, -1), X), 1)  # ?
        X = self.dropout(X + self.pos_embedding)
        for blk in self.blks:
            X = blk(X)
        return self.head(X[:, 0])

# %% [markdown]
# # 11.8.5. Training

# %%
img_size, patch_size = 96, 16
num_hiddens, mlp_num_hiddens, num_heads, num_blks = 512, 2048, 8, 2
emb_dropout, blk_dropout, lr = 0.1, 0.1, 0.1
model = ViT(img_size, patch_size, num_hiddens, mlp_num_hiddens, num_heads, num_blks, emb_dropout, blk_dropout, lr)
trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
data = d2l.FashionMNIST(batch_size=128, resize=(img_size, img_size))
trainer.fit(model, data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 7
#       5 trainer = d2l.Trainer(max_epochs=10, num_gpus=1)
#       6 data = d2l.FashionMNIST(batch_size=128, resize=(img_size, img_size))
# ----> 7 trainer.fit(model, data)
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\d2l\torch.py:285, in Trainer.fit(self, model, data)
#     283 self.val_batch_idx = 0
#     284 for self.epoch in range(self.max_epochs):
# --> 285     self.fit_epoch()
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\d2l\torch.py:298, in Trainer.fit_epoch(self)
#     296 self.model.train()
#     297 for batch in self.train_dataloader:
# --> 298     loss = self.model.training_step(self.prepare_batch(batch))
#     299     self.optim.zero_grad()
#     300     with torch.no_grad():
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\d2l\torch.py:213, in Module.training_step(self, batch)
#     212 def training_step(self, batch):
# --> 213     l = self.loss(self(*batch[:-1]), batch[-1])
#     214     self.plot('loss', l, train=True)
#     215     return l
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[8], line 21, in ViT.forward(self, X)
#      19 X = self.dropout(X + self.pos_embedding)
#      20 for blk in self.blks:
# ---> 21     X = blk(X)
#      22 return self.head(X[:, 0])
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[6], line 12, in ViTBlock.forward(self, X, valid_lens)
#      10 X = X + self.attention(*([self.ln1(X)] * 3), valid_lens)
#      11 # Equals to self.attention(self.ln1(X), self.ln1(X), self.ln1(X), valid_lens)
# ---> 12 return X + self.mlp(self.ln2(X))
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[5], line 11, in ViTMLP.forward(self, x)
#      10 def forward(self, x):
# ---> 11     return self.dropout2(self.dense2(self.dropout1(self.gelu(self.dense1(x)))))
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\_Software\miniconda3\envs\d2l\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
# Check PyTorch / d2l GPU availability
import torch
from d2l import torch as d2l

print("torch.cuda.is_available():", torch.cuda.is_available())
print("torch.cuda.device_count():", torch.cuda.device_count())
if torch.cuda.is_available():
    print("current device idx:", torch.cuda.current_device())
    print("device name:", torch.cuda.get_device_name(0))
print("d2l.try_gpu():", d2l.try_gpu())
# Out:
# torch.cuda.is_available(): False
# torch.cuda.device_count(): 0
# d2l.try_gpu(): cpu

# %%
# run in the same environment/kernel you use for the notebook
import torch
print("torch:", torch.__version__)
print("torch.version.cuda:", torch.version.cuda)
print("torch.cuda.is_available():", torch.cuda.is_available())
print("torch.cuda.device_count():", torch.cuda.device_count())
# Out:
# torch: 2.0.0+cpu
# torch.version.cuda: None
# torch.cuda.is_available(): False
# torch.cuda.device_count(): 0
